# %% [markdown]
# # LDA Topic Modeling on Abstracts (Consolidated PubMed Dataset)
#
# This notebook fulfills ALL requirements:
#
# - Topic modeling using abstracts
# - Topics with top words
# - Top 2 articles per topic (title, authors, year, journal)
# - Keyword frequency list (author + PubMed keywords)
# - Total number of articles
# - Articles per year statistics
#
# Dataset expected:
# consolidated_with_pubmed_keywords.csv

# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

import nltk
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from gensim import corpora
from gensim.models import LdaModel
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jasraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Jasraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Load dataset
df = pd.read_csv("openalex_last_5_years_with_keywords.csv")

print("Total number of articles:", len(df))

df.head()
# Out:
# Total number of articles: 1250
#                                                title  \
# 0  Intelligent Clinical Documentation: Harnessing...
# 1  Designing interpretable ML system to enhance t...
# 2  Digital proficiency: assessing knowledge, atti...
# 3  Transformative Potential of AI in Healthcare: ...
# 4  Balancing Privacy and Progress: A Review of Pr...
#
#                                              authors  pub_year  \
# 0                    Anjanava Biswas, Wrick Talukdar      2024
# 1  Elham Nasarian, Roohallah Alizadehsani, U. Raj...      2024
# 2             Ebtsam Aly Abou Hashish, Hend Alnajjar      2024
# 3  Molly Bekbolatova, Jonathan Mayer, Chi Wei Ong...      2024
# 4                  S. Williamson, Victor R. Prybutok      2024
#
#                                              journal  \
# 0  International Journal of Innovative Science an...
# 1                                 Information Fusion
# 2                              BMC Medical Education
# 3                                         Healthcare
# 4                                   Applied Sciences
#
#                                                doi  \
# 0  https://doi.org/10.38124/ijisrt/ijisrt24may1483
# 1     https://doi.org/10.1016/j.inffus.2024.102412
# 2       https://doi.org/10.1186/s12909-024-05482-3
# 3       https://doi.org/10.3390/healthcare12020125
# 4              https://doi.org/10.3390/app14020675
#
#                                        pmid  \
# 0                                       NaN
# 1                                       NaN
# 2  https://pubmed.ncbi.nlm.nih.gov/38715005
# 3  https://pubmed.ncbi.nlm.nih.gov/38255014
# 4                                       NaN
#
#                                             abstract  country  \
# 0  Comprehensive clinical documentation is crucia...  Unknown
# 1                              No abstract available       US
# 2                              No abstract available       SA
# 3  Artificial intelligence (AI) has emerged as a ...       US
# 4  Integrating Artificial Intelligence (AI) in he...       US
#
#                                             keywords raw_affiliation_recovered
# 0  Documentation, Health care, Generative grammar...                       NaN
# 1  Interpretability, Clinical decision support sy...                       NaN
# 2  Curriculum, Digital literacy, Medical educatio...                       NaN
# 3  Transformative learning, Health care, Computer...                       NaN
# 4  Health care, Autonomy, Confidentiality, Transf...                       NaN

# %%
print("\nArticles per year:")
print(df["pub_year"].value_counts().sort_index())
# Out:
# Articles per year:
# pub_year
# 2020    250
# 2021    250
# 2022    250
# 2023    250
# 2024    250
# Name: count, dtype: int64

# %%
# Text preprocessing

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):

    if pd.isna(text):
        return []
    
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    
    tokens = text.split()
    
    tokens = [
        lemmatizer.lemmatize(word)
        for word in tokens
        if word not in stop_words and len(word) > 2
    ]
    
    return tokens

df["cleaned"] = df["abstract"].apply(clean_text)

print("Example cleaned abstract:")
print(df["cleaned"].iloc[0])
# Out:
# Example cleaned abstract:
# ['comprehensive', 'clinical', 'documentation', 'crucial', 'effective', 'healthcare', 'delivery', 'yet', 'pose', 'significant', 'burden', 'healthcare', 'professional', 'leading', 'burnout', 'increased', 'medical', 'error', 'compromised', 'patient', 'safety', 'paper', 'explores', 'potential', 'generative', 'artificial', 'intelligence', 'streamline', 'clinical', 'documentation', 'process', 'specifically', 'focusing', 'generating', 'soap', 'subjective', 'objective', 'assessment', 'plan', 'birp', 'behavior', 'intervention', 'response', 'plan', 'note', 'present', 'case', 'study', 'demonstrating', 'application', 'natural', 'language', 'processing', 'nlp', 'automatic', 'speech', 'recognition', 'asr', 'technology', 'transcribe', 'patient', 'clinician', 'interaction', 'coupled', 'advanced', 'prompting', 'technique', 'generate', 'draft', 'clinical', 'note', 'using', 'large', 'language', 'model', 'llm', 'study', 'highlight', 'benefit', 'approach', 'including', 'time', 'saving', 'improved', 'documentation', 'quality', 'enhanced', 'patient', 'centered', 'care', 'additionally', 'discus', 'ethical', 'consideration', 'maintaining', 'patient', 'confidentiality', 'addressing', 'model', 'bias', 'underscoring', 'need', 'responsible', 'deployment', 'generative', 'healthcare', 'setting', 'finding', 'suggest', 'generative', 'potential', 'revolutionize', 'clinical', 'documentation', 'practice', 'alleviating', 'administrative', 'burden', 'enabling', 'healthcare', 'professional', 'focus', 'direct', 'patient', 'care']

# %%
dictionary = corpora.Dictionary(df["cleaned"])

# Improve topic quality
dictionary.filter_extremes(no_below=5, no_above=0.5)

corpus = [dictionary.doc2bow(text) for text in df["cleaned"]]

print("Dictionary size:", len(dictionary))
print("Corpus size:", len(corpus))
# Out:
# Dictionary size: 2900
# Corpus size: 1250

# %%
num_topics = 20 

lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    passes=20,
    random_state=42
)

print("LDA model trained successfully.")
# Out:
# LDA model trained successfully.

# %%
print("\nTopics and top words:")

for topic_id in range(num_topics):
    
    print("\n==========================")
    print(f"Topic {topic_id}")
    
    print(lda_model.print_topic(topic_id, topn=10))
# Out:
# Topics and top words:
#
# ==========================
# Topic 0
# 0.019*"public" + 0.018*"covid" + 0.016*"information" + 0.013*"google" + 0.012*"scholar" + 0.012*"data" + 0.011*"application" + 0.009*"pandemic" + 0.009*"vaccine" + 0.009*"risk"
#
# ==========================
# Topic 1
# 0.018*"drug" + 0.012*"research" + 0.012*"human" + 0.011*"based" + 0.011*"review" + 0.010*"intervention" + 0.010*"trial" + 0.010*"recognition" + 0.009*"artificial" + 0.009*"clinical"
#
# ==========================
# Topic 2
# 0.046*"covid" + 0.031*"pandemic" + 0.022*"online" + 0.020*"information" + 0.018*"social" + 0.018*"digital" + 0.017*"medium" + 0.011*"communication" + 0.010*"behavior" + 0.010*"use"
#
# ==========================
# Topic 3
# 0.018*"model" + 0.014*"machine" + 0.014*"bias" + 0.013*"learning" + 0.012*"patient" + 0.010*"problem" + 0.009*"scholar" + 0.008*"prediction" + 0.008*"google" + 0.007*"fairness"
#
# ==========================
# Topic 4
# 0.040*"data" + 0.021*"communication" + 0.016*"non" + 0.011*"robot" + 0.009*"driven" + 0.009*"monitoring" + 0.009*"user" + 0.008*"behavioral" + 0.008*"learning" + 0.008*"design"
#
# ==========================
# Topic 5
# 0.021*"healthcare" + 0.018*"model" + 0.014*"decision" + 0.011*"intelligence" + 0.011*"learning" + 0.011*"artificial" + 0.011*"trust" + 0.010*"xai" + 0.009*"human" + 0.009*"research"
#
# ==========================
# Topic 6
# 0.027*"metaverse" + 0.025*"healthcare" + 0.020*"virtual" + 0.016*"patient" + 0.016*"physical" + 0.010*"chatbots" + 0.009*"application" + 0.009*"potential" + 0.009*"medical" + 0.009*"based"
#
# ==========================
# Topic 7
# 0.018*"system" + 0.017*"intelligence" + 0.015*"artificial" + 0.013*"data" + 0.012*"machine" + 0.011*"learning" + 0.010*"sensor" + 0.010*"technology" + 0.009*"application" + 0.009*"human"
#
# ==========================
# Topic 8
# 0.029*"digital" + 0.024*"care" + 0.015*"technology" + 0.009*"trust" + 0.008*"tool" + 0.008*"need" + 0.007*"clinical" + 0.007*"literacy" + 0.007*"use" + 0.007*"approach"
#
# ==========================
# Topic 9
# 0.173*"abstract" + 0.170*"available" + 0.024*"dhl" + 0.011*"covid" + 0.011*"information" + 0.010*"digital" + 0.008*"pandemic" + 0.008*"group" + 0.007*"student" + 0.007*"online"
#
# ==========================
# Topic 10
# 0.029*"patient" + 0.019*"communication" + 0.017*"digital" + 0.013*"care" + 0.013*"vaccine" + 0.009*"tool" + 0.009*"healthcare" + 0.007*"professional" + 0.007*"technology" + 0.007*"physician"
#
# ==========================
# Topic 11
# 0.029*"healthcare" + 0.019*"iot" + 0.019*"data" + 0.018*"technology" + 0.017*"smart" + 0.015*"application" + 0.013*"communication" + 0.013*"learning" + 0.012*"based" + 0.011*"device"
#
# ==========================
# Topic 12
# 0.023*"healthcare" + 0.019*"explanation" + 0.016*"artificial" + 0.014*"intelligence" + 0.012*"study" + 0.009*"participant" + 0.008*"trust" + 0.008*"human" + 0.008*"system" + 0.008*"performance"
#
# ==========================
# Topic 13
# 0.041*"mental" + 0.017*"human" + 0.015*"interaction" + 0.011*"social" + 0.011*"service" + 0.010*"journal" + 0.009*"study" + 0.008*"patient" + 0.007*"education" + 0.007*"use"
#
# ==========================
# Topic 14
# 0.046*"digital" + 0.035*"twin" + 0.024*"system" + 0.017*"technology" + 0.012*"physical" + 0.011*"user" + 0.010*"healthcare" + 0.009*"model" + 0.007*"data" + 0.007*"risk"
#
# ==========================
# Topic 15
# 0.055*"literacy" + 0.042*"digital" + 0.021*"study" + 0.017*"student" + 0.014*"education" + 0.010*"level" + 0.009*"information" + 0.008*"use" + 0.008*"healthcare" + 0.008*"among"
#
# ==========================
# Topic 16
# 0.029*"healthcare" + 0.023*"patient" + 0.023*"data" + 0.019*"ethical" + 0.012*"challenge" + 0.010*"technology" + 0.009*"intelligence" + 0.009*"artificial" + 0.008*"potential" + 0.008*"system"
#
# ==========================
# Topic 17
# 0.045*"trust" + 0.033*"user" + 0.016*"healthcare" + 0.014*"medical" + 0.014*"system" + 0.013*"design" + 0.012*"transparency" + 0.010*"perceived" + 0.009*"doctor" + 0.009*"expert"
#
# ==========================
# Topic 18
# 0.050*"data" + 0.027*"system" + 0.019*"privacy" + 0.018*"security" + 0.017*"patient" + 0.014*"blockchain" + 0.013*"iot" + 0.011*"trust" + 0.009*"proposed" + 0.009*"digital"
#
# ==========================
# Topic 19
# 0.027*"chatgpt" + 0.013*"language" + 0.011*"research" + 0.011*"model" + 0.010*"potential" + 0.009*"healthcare" + 0.009*"medical" + 0.008*"care" + 0.008*"clinical" + 0.008*"use"

# %%
def get_top_docs_for_topic(topic_id, top_n=2):

    topic_scores = []

    for i, row in df.iterrows():

        bow = dictionary.doc2bow(row["cleaned"])

        topics = lda_model.get_document_topics(bow)

        score = 0
        
        for t, prob in topics:
            if t == topic_id:
                score = prob

        topic_scores.append(score)

    df_temp = df.copy()
    
    df_temp["topic_score"] = topic_scores

    return df_temp.sort_values("topic_score", ascending=False)[
        ["title", "authors", "pub_year", "journal"]
    ].head(top_n)


print("\nTop articles per topic:")

for topic_id in range(num_topics):

    print("\n==========================")
    print(f"TOPIC {topic_id}")
    
    print("\nTop Words:")
    print(lda_model.print_topic(topic_id))
    
    print("\nTop Articles:")
    print(get_top_docs_for_topic(topic_id))
# Out:
# Top articles per topic:
#
# ==========================
# TOPIC 0
#
# Top Words:
# 0.019*"public" + 0.018*"covid" + 0.016*"information" + 0.013*"google" + 0.012*"scholar" + 0.012*"data" + 0.011*"application" + 0.009*"pandemic" + 0.009*"vaccine" + 0.009*"risk"
#
# Top Articles:
#                                                   title            authors  \
# 368                         Government at a Glance 2023               OECD
# 1119  Spreading (Dis)Trust: Covid-19 Misinformation ...  Alessandro Lovari
#
#       pub_year                  journal
# 368       2023   Government at a glance
# 1119      2020  Media and Communication
#
# ==========================
# TOPIC 1
#
# Top Words:
# 0.018*"drug" + 0.012*"research" + 0.012*"human" + 0.011*"based" + 0.011*"review" + 0.010*"intervention" + 0.010*"trial" + 0.010*"recognition" + 0.009*"artificial" + 0.009*"clinical"
#
# Top Articles:
#                                                   title  \
# 1049  Guidelines for clinical trial protocols for in...
# 1025  Reporting guidelines for clinical trial report...
#
#                                                 authors  pub_year journal
# 1049  Samantha Cruz Rivera, Xiaoxuan Liu, An‐Wen Cha...      2020     BMJ
# 1025  Xiaoxuan Liu, Samantha Cruz Rivera, David Mohe...      2020     BMJ
#
# ==========================
# TOPIC 2
#
# Top Words:
# 0.046*"covid" + 0.031*"pandemic" + 0.022*"online" + 0.020*"information" + 0.018*"social" + 0.018*"digital" + 0.017*"medium" + 0.011*"communication" + 0.010*"behavior" + 0.010*"use"
#
# Top Articles:
#                                                   title  \
# 596   Digital Media Use and Adolescents' Mental Heal...
# 1129  Changes in Digital Communication During the CO...
#
#                                                 authors  pub_year  \
# 596   Laura Marciano, Michelle Ostroumova, Peter J. ...      2022
# 1129  Minh Hao Nguyen, Jonathan Gruber, Jaelle Fuchs...      2020
#
#                          journal
# 596   Frontiers in Public Health
# 1129      Social Media + Society
#
# ==========================
# TOPIC 3
#
# Top Words:
# 0.018*"model" + 0.014*"machine" + 0.014*"bias" + 0.013*"learning" + 0.012*"patient" + 0.010*"problem" + 0.009*"scholar" + 0.008*"prediction" + 0.008*"google" + 0.007*"fairness"
#
# Top Articles:
#                                                   title  \
# 1112  Ethical limitations of algorithmic fairness so...
# 797   Artificial Intelligence for the Future Radiolo...
#
#                                                 authors  pub_year  \
# 1112  Melissa D. McCradden, Shalmali Joshi, Mjaye Ma...      2020
# 797   Seong K. Mun, Kenneth H. Wong, Shih‐Chung B. L...      2021
#
#                                  journal
# 1112           The Lancet Digital Health
# 797   Frontiers in Molecular Biosciences
#
# ==========================
# TOPIC 4
#
# Top Words:
# 0.040*"data" + 0.021*"communication" + 0.016*"non" + 0.011*"robot" + 0.009*"driven" + 0.009*"monitoring" + 0.009*"user" + 0.008*"behavioral" + 0.008*"learning" + 0.008*"design"
#
# Top Articles:
#                                                  title  \
# 142     Federated Learning With Non-IID Data: A Survey
# 823  A healthy debate: Exploring the views of medic...
#
#                                                authors  pub_year  \
# 142  Zili Lu, Heng Pan, Yueyue Dai, Xueming Si, Yan...      2024
# 823   Andreia Martinho, Maarten Kroesen, Caspar Chorus      2021
#
#                                  journal
# 142      IEEE Internet of Things Journal
# 823  Artificial Intelligence in Medicine
#
# ==========================
# TOPIC 5
#
# Top Words:
# 0.021*"healthcare" + 0.018*"model" + 0.014*"decision" + 0.011*"intelligence" + 0.011*"learning" + 0.011*"artificial" + 0.011*"trust" + 0.010*"xai" + 0.009*"human" + 0.009*"research"
#
# Top Articles:
#                                                  title  \
# 225  An Explainable AI Paradigm for Alzheimer’s Dia...
# 286  Choosing human over AI doctors? How comparativ...
#
#                                                authors  pub_year  \
# 225  Tanjim Mahmud, Koushick Barua, Sultana Umme Ha...      2024
# 286     Sophie Kerstan, Nadine Bienefeld, Gudela Grote      2023
#
#            journal
# 225    Diagnostics
# 286  Risk Analysis
#
# ==========================
# TOPIC 6
#
# Top Words:
# 0.027*"metaverse" + 0.025*"healthcare" + 0.020*"virtual" + 0.016*"patient" + 0.016*"physical" + 0.010*"chatbots" + 0.009*"application" + 0.009*"potential" + 0.009*"medical" + 0.009*"based"
#
# Top Articles:
#                                                  title  \
# 256  A Review of the Role of Artificial Intelligenc...
# 395  Applications of Artificial Intelligence in the...
#
#                                                authors  pub_year  \
# 256  Ahmed Al Kuwaiti, Khalid Nazer, Abdullah H. Al...      2023
# 395  Kevin Pierre, Adam G. Haneberg, Sean Kwak, Kei...      2023
#
#                               journal
# 256  Journal of Personalized Medicine
# 395         Seminars in Roentgenology
#
# ==========================
# TOPIC 7
#
# Top Words:
# 0.018*"system" + 0.017*"intelligence" + 0.015*"artificial" + 0.013*"data" + 0.012*"machine" + 0.011*"learning" + 0.010*"sensor" + 0.010*"technology" + 0.009*"application" + 0.009*"human"
#
# Top Articles:
#                                                   title  \
# 1084  State-of-the-Art Artificial Intelligence Techn...
# 340   A Machine Learning-Combined Flexible Sensor fo...
#
#                                                 authors  pub_year  \
# 1084                      Syed Saqib Ali, Bong Jun Choi      2020
# 340   Jiawang Xie, Yuzhi Zhao, Dezhi Zhu, Jianfeng Y...      2023
#
#                                  journal
# 1084                         Electronics
# 340   ACS Applied Materials & Interfaces
#
# ==========================
# TOPIC 8
#
# Top Words:
# 0.029*"digital" + 0.024*"care" + 0.015*"technology" + 0.009*"trust" + 0.008*"tool" + 0.008*"need" + 0.007*"clinical" + 0.007*"literacy" + 0.007*"use" + 0.007*"approach"
#
# Top Articles:
#                                                  title  \
# 499  AI Implementation in Health Care: The Role of ...
# 481  Digital health platforms for the elderly? Key ...
#
#                                                authors  pub_year  \
# 499                     Zhanna Novikov, Tal Katz–Navon      2023
# 481  Johan Frishammar, Anna Essén, Frida Bergström,...      2023
#
#                                          journal
# 499            Academy of Management Proceedings
# 481  Technological Forecasting and Social Change
#
# ==========================
# TOPIC 9
#
# Top Words:
# 0.173*"abstract" + 0.170*"available" + 0.024*"dhl" + 0.011*"covid" + 0.011*"information" + 0.010*"digital" + 0.008*"pandemic" + 0.008*"group" + 0.007*"student" + 0.007*"online"
#
# Top Articles:
#                                                   title  \
# 1168  Report on Digital Literacy in Academic Meeting...
# 957   COVID-19 and Health Information Seeking Behavi...
#
#                                                 authors  pub_year  \
# 1168                                         Carol Nash      2020
# 957   Rubeena Zakar, Sarosh Iqbal, Muhammad Zakria Z...      2021
#
#             journal
# 1168     Challenges
# 957   Preprints.org
#
# ==========================
# TOPIC 10
#
# Top Words:
# 0.029*"patient" + 0.019*"communication" + 0.017*"digital" + 0.013*"care" + 0.013*"vaccine" + 0.009*"tool" + 0.009*"healthcare" + 0.007*"professional" + 0.007*"technology" + 0.007*"physician"
#
# Top Articles:
#                                                   title  \
# 44    Revolutionizing community health literacy: The...
# 1242                                 Rise of the Robots
#
#                                                 authors  pub_year  \
# 44    Chukwudi Cosmos Maha, Tolulope Olagoke Kolawol...      2024
# 1242        D. Watson, Joshua Womack, Suzanne Papadakos      2020
#
#                                 journal
# 44    GSC Advanced Research and Reviews
# 1242    Critical Care Nursing Quarterly
#
# ==========================
# TOPIC 11
#
# Top Words:
# 0.029*"healthcare" + 0.019*"iot" + 0.019*"data" + 0.018*"technology" + 0.017*"smart" + 0.015*"application" + 0.013*"communication" + 0.013*"learning" + 0.012*"based" + 0.011*"device"
#
# Top Articles:
#                                                   title  \
# 1055  A Novel Smart Healthcare Design, Simulation, a...
# 407   Federated learning for secure IoMT-application...
#
#                                                 authors  pub_year  \
# 1055  Adarsh Kumar, Rajalakshmi Krishnamurthi, Anand...      2020
# 407   Sita Rani, Aman Kataria, Sachin Kumar, Prayag ...      2023
#
#                       journal
# 1055              IEEE Access
# 407   Knowledge-Based Systems
#
# ==========================
# TOPIC 12
#
# Top Words:
# 0.023*"healthcare" + 0.019*"explanation" + 0.016*"artificial" + 0.014*"intelligence" + 0.012*"study" + 0.009*"participant" + 0.008*"trust" + 0.008*"human" + 0.008*"system" + 0.008*"performance"
#
# Top Articles:
#                                                  title  \
# 726  Future of healthcare start-ups in the era of d...
# 700  Towards a data collection methodology for Resp...
#
#                                                authors  pub_year  \
# 726                     Aswathy Sreenivasan, M. Suresh      2022
# 700  Andreea M. Oprescu, G. Miró Amarante, Lutgardo...      2022
#
#                                                journal
# 726  International Journal of Industrial Engineerin...
# 700                                 Information Fusion
#
# ==========================
# TOPIC 13
#
# Top Words:
# 0.041*"mental" + 0.017*"human" + 0.015*"interaction" + 0.011*"social" + 0.011*"service" + 0.010*"journal" + 0.009*"study" + 0.008*"patient" + 0.007*"education" + 0.007*"use"
#
# Top Articles:
#                                                   title  \
# 1156  Artificial intelligence, bureaucratic form, an...
# 1177  &lt;p&gt;The Mental Health Impact of the COVID...
#
#                                            authors  pub_year  \
# 1156  Justin B. Bullock, Matthew Young, Yifan Wang      2020
# 1177              Bazghina‐werq Semo, Souci Frissa      2020
#
#                                           journal
# 1156                           Information Polity
# 1177  Psychology Research and Behavior Management
#
# ==========================
# TOPIC 14
#
# Top Words:
# 0.046*"digital" + 0.035*"twin" + 0.024*"system" + 0.017*"technology" + 0.012*"physical" + 0.011*"user" + 0.010*"healthcare" + 0.009*"model" + 0.007*"data" + 0.007*"risk"
#
# Top Articles:
#                                                  title  \
# 960  Towards next generation cyber-physical systems...
# 668  A Systematic Review on Healthcare Artificial I...
#
#                                                authors  pub_year  \
# 960  Abiola Akanmu, Chimay Anumba, Omobolanle Oguns...      2021
# 668  Abdullah Bin Sawad, Bhuva Narayan, Ahlam Alnef...      2022
#
#                                                journal
# 960  Journal of Information Technology in Construction
# 668                                            Sensors
#
# ==========================
# TOPIC 15
#
# Top Words:
# 0.055*"literacy" + 0.042*"digital" + 0.021*"study" + 0.017*"student" + 0.014*"education" + 0.010*"level" + 0.009*"information" + 0.008*"use" + 0.008*"healthcare" + 0.008*"among"
#
# Top Articles:
#                                                  title  \
# 781  Addressing Health Literacy in Schools in Germa...
# 684  Health Literacy in Portugal: Results of the He...
#
#                                                authors  pub_year  \
# 781  Tessa Schulenkorf, Verena Krah, Kevin Dadaczyn...      2021
# 684  Miguel Arriaga, Rita Francisco, Paulo Nogueira...      2022
#
#                                                journal
# 781                         Frontiers in Public Health
# 684  International Journal of Environmental Researc...
#
# ==========================
# TOPIC 16
#
# Top Words:
# 0.029*"healthcare" + 0.023*"patient" + 0.023*"data" + 0.019*"ethical" + 0.012*"challenge" + 0.010*"technology" + 0.009*"intelligence" + 0.009*"artificial" + 0.008*"potential" + 0.008*"system"
#
# Top Articles:
#                                                  title  \
# 191  Ethical considerations in AI-enhanced medical ...
# 278  Ethical implications of AI and robotics in hea...
#
#                                                authors  pub_year  \
# 191  Tolulope Olorunsogo, Adekunle Oyeyemi Adenyi, ...      2024
# 278  Chukwuka Elendu, Dependable C. Amaechi, Tochi ...      2023
#
#                                                journal
# 191  World Journal of Advanced Engineering Technolo...
# 278                                           Medicine
#
# ==========================
# TOPIC 17
#
# Top Words:
# 0.045*"trust" + 0.033*"user" + 0.016*"healthcare" + 0.014*"medical" + 0.014*"system" + 0.013*"design" + 0.012*"transparency" + 0.010*"perceived" + 0.009*"doctor" + 0.009*"expert"
#
# Top Articles:
#                                                   title  \
# 551   Transparency of AI in Healthcare as a Multilay...
# 1216  Trust in Artificial Intelligence: Australian I...
#
#                                                 authors  pub_year  \
# 551   Anastasiya Kiseleva, Dimitris Kotzinos, Paul D...      2022
# 1216    Steven Lockey, Nicole Gillespie, Caitlin Curtis      2020
#
#                                    journal
# 551   Frontiers in Artificial Intelligence
# 1216                        Unknown Source
#
# ==========================
# TOPIC 18
#
# Top Words:
# 0.050*"data" + 0.027*"system" + 0.019*"privacy" + 0.018*"security" + 0.017*"patient" + 0.014*"blockchain" + 0.013*"iot" + 0.011*"trust" + 0.009*"proposed" + 0.009*"digital"
#
# Top Articles:
#                                                   title  \
# 941                            Building the New Economy
# 1081  Comparative Toxicogenomics Database (CTD): upd...
#
#                                                 authors  pub_year  \
# 941    Alex Pentland, Alexander Lipton, Thomas Hardjono      2021
# 1081  Allan Peter Davis, Cynthia Grondin, Robin J. J...      2020
#
#                      journal
# 941     The MIT Press eBooks
# 1081  Nucleic Acids Research
#
# ==========================
# TOPIC 19
#
# Top Words:
# 0.027*"chatgpt" + 0.013*"language" + 0.011*"research" + 0.011*"model" + 0.010*"potential" + 0.009*"healthcare" + 0.009*"medical" + 0.008*"care" + 0.008*"clinical" + 0.008*"use"
#
# Top Articles:
#                                                  title       authors  \
# 252  ChatGPT Utility in Healthcare Education, Resea...  Malik Sallam
# 298  The Utility of ChatGPT as an Example of Large ...  Malik Sallam
#
#      pub_year         journal
# 252      2023      Healthcare
# 298      2023  Unknown Source

# %%
from collections import Counter
import pandas as pd

keyword_counter = Counter()

# Only one keyword column exists: "keywords"
for keywords in df["keywords"]:
    if pd.notna(keywords):
        words = [
            k.strip().lower()
            for k in str(keywords).split("|")
        ]
        keyword_counter.update(words)

print("\nTop 20 most frequent keywords:")
for keyword, freq in keyword_counter.most_common(20):
    print(f"{keyword}: {freq}")
# Out:
# Top 20 most frequent keywords:
# computer science, artificial intelligence: 3
# psychology, computer science, artificial intelligence: 2
# business: 2
# documentation, health care, generative grammar, confidentiality, process (computing), software deployment, intervention (counseling), patient safety, computer science, medicine, artificial intelligence, nursing, computer security, software engineering, operating system, programming language, economic growth, economics: 1
# interpretability, clinical decision support system, computer science, health care, decision support system, mhealth, knowledge management, digital health, health informatics, process (computing), artificial intelligence, telemedicine, data science, psychological intervention, medicine, nursing, economic growth, operating system, economics: 1
# curriculum, digital literacy, medical education, digital transformation, psychology, health care, descriptive statistics, computer literacy, nursing, medicine, computer science, mathematics education, pedagogy, mathematics, economic growth, economics, statistics, world wide web: 1
# transformative learning, health care, computer science, artificial intelligence, knowledge management, psychology, political science, law, pedagogy: 1
# health care, autonomy, confidentiality, transformative learning, information privacy, data sharing, data governance, corporate governance, business, internet privacy, knowledge management, political science, psychology, computer science, medicine, computer security, law, service (business), data quality, marketing, alternative medicine, pedagogy, pathology, finance: 1
# in silico, personalized medicine, drug development, precision medicine, health care, medicine, drug, pharmacology, clinical pharmacology, systems pharmacology, medical physics, computational biology, bioinformatics, biology, pathology, biochemistry, gene, economics, economic growth: 1
# health care, direct anonymous attestation, computer science, internet privacy, engineering ethics, computer security, knowledge management, psychology, trusted computing, political science, engineering, law: 1
# health care, workflow, knowledge management, computer science, transparency (behavior), business, computer security, database, economic growth, economics: 1
# psychology, health care, artificial intelligence, computer science, data science, political science, law: 1
# clinical decision support system, workflow, interpretability, usability, artificial intelligence, computer science, health care, transformative learning, decision support system, knowledge management, data science, psychology, human–computer interaction, political science, database, pedagogy, law: 1
# health literacy, digital health, literacy, diversity (politics), public health, environmental health, medicine, psychology, health care, political science, nursing, pedagogy, law: 1
# health care, safeguarding, context (archaeology), transformative learning, medicine, public relations, knowledge management, psychology, nursing, computer science, political science, paleontology, biology, law, pedagogy: 1
# health care, health informatics, generative grammar, knowledge management, health administration, corporate governance, process management, medicine, artificial intelligence, computer science, public health, business, nursing, political science, finance, law: 1
# health literacy, digital health, ehealth, literacy, digital literacy, terminology, cinahl, context (archaeology), knowledge management, psychological intervention, psychology, public relations, health care, computer science, medicine, political science, pedagogy, nursing, geography, philosophy, linguistics, law, archaeology: 1
# health literacy, digital health, digital literacy, literacy, mental health, knowledge management, health care, public relations, computer science, psychology, medical education, medicine, pedagogy, political science, psychotherapist, law: 1
# transparency (behavior), health care, business, knowledge management, computer science, political science, computer security, law: 1
# mental health, psychology, health care, medical diagnosis, anxiety, transformative learning, psychiatry, medicine, developmental psychology, economic growth, economics, pathology: 1

# %%
#------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Define the Topic Name Map based on your output
topic_names = {
    0: "Digital Health Technology & Patient Care",
    1: "Molecular Biology & Gene–Protein Interactions",
    2: "Patient Outcomes, Mortality & Trust in Healthcare",
    3: "Clinical Risk Prediction Models",
    4: "Public Health & Digital Healthcare Systems",
    5: "Infectious Diseases (HIV & Lung Infections)",
    6: "Social Media & Digital Health Communication",
    7: "Healthcare Services & Patient Care Research",
    8: "Machine Learning in Clinical Data Analysis",
    9: "Viral Diseases & Molecular Medicine",
    10: "Mobile Health (mHealth) Applications & Health Apps",
    11: "Digital Health Data Analytics & Research Methods",
    12: "Healthcare Quality & Treatment Evaluation",
    13: "Patient Monitoring & Chronic Disease Management",
    14: "Digital Health Interventions in Populations",
    15: "Artificial Intelligence in Healthcare Systems",
    16: "Large Language Models in Healthcare (ChatGPT, LLMs)",
    17: "Online Health Information & Website Readability",
    18: "Cancer Risk & Clinical Treatment Studies",
    19: "Medical Data Modeling & Predictive Healthcare"
}

# 2. Assign Dominant Topic and Name to the DataFrame
def get_dominant_topic(bow):
    probs = lda_model.get_document_topics(bow)
    return sorted(probs, key=lambda x: x[1], reverse=True)[0][0]

df["dominant_topic"] = [
    get_dominant_topic(dictionary.doc2bow(text))
    for text in df["cleaned"]
]

df["topic_name"] = df["dominant_topic"].map(topic_names)

# 3. Create the Year vs Cluster Trend Data
trend_df = df.groupby(["pub_year", "topic_name"]).size().unstack(fill_value=0)

# -------------------------------
# 4. Visualization (ONLY 2022–2026)
# -------------------------------
trend_recent = trend_df.loc[2022:2026]

plt.figure(figsize=(16, 9))
palette = sns.color_palette("husl", len(topic_names))

sns.lineplot(
    data=trend_recent,
    dashes=False,
    marker="o",
    palette=palette,
    linewidth=2
)

plt.title("Evolution of Research Clusters (2022 - 2026)", fontsize=18, pad=20)
plt.xlabel("Year of Publication", fontsize=14)
plt.ylabel("Number of Articles", fontsize=14)

plt.legend(
    title="Research Clusters",
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    fontsize=10
)

plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# -------------------------------
# 5. Recent Cluster Activity Table (2022–2026)
# -------------------------------
print("\nRecent Cluster Activity (2022–2026):")
print(trend_recent.T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 35
#      30     probs = lda_model.get_document_topics(bow)
#      31     return sorted(probs, key=lambda x: x[1], reverse=True)[0][0]
#      33 df["dominant_topic"] = [
#      34     get_dominant_topic(dictionary.doc2bow(text))
# ---> 35     for text in df["cleaned"]
#      36 ]
#      38 df["topic_name"] = df["dominant_topic"].map(topic_names)
#      40 # 3. Create the Year vs Cluster Trend Data
#
# NameError: name 'df' is not defined

# %%
# ========== GENERATE TOPIC NAME FROM TOP WORDS ==========

def generate_topic_name(topic_id, topn=3):
    """
    Create readable topic name using top words.
    Example: 'blockchain + healthcare + security'
    """
    words_probs = lda_model.show_topic(topic_id, topn=topn)
    words = [word.capitalize() for word, _ in words_probs]
    
    return " + ".join(words)


# ========== FORMAT FULL CITATION ==========
def format_citation(row):
    authors = str(row["authors"]).strip()
    year = str(row["pub_year"]).strip()
    title = str(row["title"]).strip()
    journal = str(row["journal"]).strip()
    
    return f"{authors}. ({year}). {title}. {journal}."


# ========== EXPORT STRUCTURED FILE ==========
output_file = "topic_top_articles_with_names.txt"

with open(output_file, "w", encoding="utf-8") as f:

    for topic_id in range(num_topics):
        
        topic_name = generate_topic_name(topic_id)
        
        f.write(f"\n===== {topic_name} =====\n")
        
        top_docs = get_top_docs_for_topic(topic_id, top_n=2)
        
        for _, row in top_docs.iterrows():
            citation = format_citation(row)
            f.write(citation + "\n")

print(f"\nStructured topic citations exported to {output_file}")
# Out:
# Structured topic citations exported to topic_top_articles_with_names.txt

# %%
# ========== EXPORT WITH CUSTOM TOPIC NAMES ==========

def format_citation(row):
    authors = str(row["authors"]).strip()
    year = str(row["pub_year"]).strip()
    title = str(row["title"]).strip()
    journal = str(row["journal"]).strip()
    
    return f"{authors}. ({year}). {title}. {journal}."

output_file = "Recent_Cluster_Activity_2024_2026.txt"

with open(output_file, "w", encoding="utf-8") as f:
    
    f.write("Recent Cluster Activity (2024-2026)\n")
    f.write("=====================================\n\n")

    for topic_id in range(num_topics):
        
        topic_label = topic_names.get(topic_id, f"Topic {topic_id}")
        
        f.write(f"\n===== {topic_label} =====\n")
        
        top_docs = get_top_docs_for_topic(topic_id, top_n=2)
        
        for _, row in top_docs.iterrows():
            citation = format_citation(row)
            f.write(citation + "\n")

print(f"\nFile exported successfully: {output_file}")
# Out:
# File exported successfully: Recent_Cluster_Activity_2024_2026.txt

# %%
print("Total number of articles:", len(df))

# -----------------------------
# CLEAN + SPLIT KEYWORDS
# -----------------------------

def split_keywords(cell):
    """
    Handles things like:
    "precision, blockchain, digital, twins, trust"
    or "precision | blockchain | digital twins"
    and returns:
    ["precision", "blockchain", "digital", "twins", "trust"]
    """
    if pd.isna(cell):
        return []
    
    text = str(cell).lower()
    
    # Normalize separators: treat '|' as ','
    text = text.replace("|", ",")
    
    parts = [p.strip() for p in text.split(",")]
    parts = [p for p in parts if p]  # remove empty
    
    return parts

# Apply to the ONLY keyword column
df["author_kw_list"] = df["keywords"].apply(split_keywords)

# -----------------------------
# COUNT INDIVIDUAL KEYWORDS
# -----------------------------

keyword_counter = Counter()

for kw_list in df["author_kw_list"]:
    keyword_counter.update(kw_list)

# -----------------------------
# BUILD FINAL TABLE: ONE KEYWORD PER ROW
# -----------------------------

keyword_freq_df = pd.DataFrame(
    keyword_counter.items(),
    columns=["keyword", "frequency"]
).sort_values("frequency", ascending=False)

print("\nTop 20 most frequent individual keywords:")
print(keyword_freq_df.head(20))

# -----------------------------
# SAVE TO CSV
# -----------------------------

keyword_freq_df.to_csv("keyword_frequency.csv", index=False)

print("\nSaved keyword frequencies to: keyword_frequency.csv")
# Out:
# Total number of articles: 1250
#
# Top 20 most frequent individual keywords:
#                     keyword  frequency
# 8          computer science       1024
# 1               health care        683
# 9                  medicine        620
# 41        political science        526
# 10  artificial intelligence        517
# 42                      law        502
# 32               psychology        502
# 17                economics        376
# 16          economic growth        338
# 26             data science        311
# 22     knowledge management        262
# 12        computer security        260
# 73              engineering        239
# 48                 business        227
# 54                pathology        224
# 39           world wide web        216
# 11                  nursing        211
# 14         operating system        188
# 36                 pedagogy        182
# 67                  biology        181
#
# Saved keyword frequencies to: keyword_frequency.csv

# %%
# Keywords co-occurrence network (no external community package)
import pandas as pd
import numpy as np
from collections import Counter
import itertools
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------- PARAMETERS ----------------
MIN_KEYWORD_FREQ = 5       # drop keywords with frequency < this
MIN_EDGE_WEIGHT = 2        # drop co-occurrence edges with weight < this
TOP_LABEL_N = 40           # how many top keywords to label
FIGSIZE = (14, 14)
SEED = 42

# ---------------- PREP: expects df["author_kw_list"] to exist ----------------
# If not present, create it using your split_keywords function:
# df["author_kw_list"] = df["keywords"].apply(split_keywords)

kw_lists = df["author_kw_list"].dropna().tolist()

# count keyword frequencies
kw_counter = Counter()
for kws in kw_lists:
    kw_counter.update(kws)

# filter low-frequency keywords
valid_keywords = {k for k, v in kw_counter.items() if v >= MIN_KEYWORD_FREQ}

# build co-occurrence counts (unordered pairs, deduplicated per document)
cooc = Counter()
for kws in kw_lists:
    kws_filtered = [k for k in kws if k in valid_keywords]
    kws_unique = sorted(set(kws_filtered))
    for a, b in itertools.combinations(kws_unique, 2):
        cooc[(a, b)] += 1

# build edges DataFrame and filter by weight
edges_df = pd.DataFrame(
    [(a, b, w) for (a, b), w in cooc.items() if w >= MIN_EDGE_WEIGHT],
    columns=["kw_a", "kw_b", "weight"]
).sort_values("weight", ascending=False).reset_index(drop=True)

# build frequency DataFrame for nodes
freq_df = pd.DataFrame(list(kw_counter.items()), columns=["keyword", "frequency"])
freq_df = freq_df[freq_df["keyword"].isin(valid_keywords)].sort_values("frequency", ascending=False)

# ---------------- BUILD GRAPH ----------------
G = nx.Graph()
for _, r in freq_df.iterrows():
    G.add_node(r["keyword"], frequency=int(r["frequency"]))
for _, r in edges_df.iterrows():
    if r["kw_a"] in G.nodes and r["kw_b"] in G.nodes:
        G.add_edge(r["kw_a"], r["kw_b"], weight=int(r["weight"]))

print(f"Graph built: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# ---------------- COMMUNITY DETECTION (networkx built-in) ----------------
# Use greedy modularity communities (no external dependency)
from networkx.algorithms import community as nx_comm

communities = list(nx_comm.greedy_modularity_communities(G))
# convert to partition dict: node -> cluster_id
partition = {}
for cid, comm in enumerate(communities):
    for node in comm:
        partition[node] = cid

nx.set_node_attributes(G, partition, "cluster")
clusters = sorted(set(partition.values()))

# color map for clusters
palette = sns.color_palette("tab10", n_colors=max(10, len(clusters)))
cluster_colors = {c: palette[i % len(palette)] for i, c in enumerate(clusters)}
node_color_list = [cluster_colors[partition[n]] for n in G.nodes()]

# ---------------- LAYOUT ----------------
spring_pos = nx.spring_layout(G, seed=SEED, k=None, iterations=200)
nodes = list(G.nodes())
angle = np.linspace(0, 2 * np.pi, len(nodes), endpoint=False)
circle_pos = {n: (np.cos(a), np.sin(a)) for n, a in zip(nodes, angle)}
pos = {n: 0.35 * np.array(spring_pos[n]) + 0.65 * np.array(circle_pos[n]) for n in nodes}

# ---------------- DRAW ----------------
plt.figure(figsize=FIGSIZE)
edge_weights = np.array([G[u][v]["weight"] for u, v in G.edges()]) if G.number_of_edges() > 0 else np.array([])
edge_widths = (0.5 + 3.0 * (edge_weights / edge_weights.max())) if edge_weights.size else 0.5

freqs = np.array([G.nodes[n]["frequency"] for n in G.nodes()])
node_sizes = 200 * (freqs / freqs.max()) + 50

nx.draw_networkx_edges(G, pos, alpha=0.35, width=edge_widths, edge_color="#999999")
nx.draw_networkx_nodes(
    G, pos,
    node_size=node_sizes,
    node_color=node_color_list,
    linewidths=0.6,
    edgecolors="black",
    alpha=0.95
)

top_labels = set(freq_df.head(TOP_LABEL_N)["keyword"].tolist())
labels = {n: n for n in G.nodes() if n in top_labels}
nx.draw_networkx_labels(G, pos, labels=labels, font_size=9, font_family="sans-serif")

plt.title("Keyword Co-occurrence Network (node size = frequency; color = cluster)", fontsize=16)
plt.axis("off")

from matplotlib.patches import Patch
legend_handles = [Patch(facecolor=cluster_colors[c], edgecolor="k", label=f"Cluster {c}") for c in clusters]
plt.legend(handles=legend_handles, bbox_to_anchor=(1.02, 1), loc="upper left", title="Clusters")

plt.tight_layout()
plt.show()

# ---------------- EXPORTS ----------------
nx.write_gexf(G, "keyword_cooccurrence_network.gexf")
edges_df.to_csv("keyword_cooccurrence_edges.csv", index=False)
freq_df.to_csv("keyword_frequencies_filtered.csv", index=False)
cluster_df = pd.DataFrame([{"keyword": n, "frequency": G.nodes[n]["frequency"], "cluster": partition[n]} for n in G.nodes()])
cluster_df.to_csv("keyword_clusters.csv", index=False)
# Out:
# Graph built: 379 nodes, 11381 edges

# %%
# 1. Add a Retrieval Layer (TF‑IDF + Cosine Similarity
# This lets your notebook answer user queries

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Join cleaned tokens back into text
df["cleaned_text"] = df["cleaned"].apply(lambda x: " ".join(x))

vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = vectorizer.fit_transform(df["cleaned_text"])

def search_papers(query, top_n=15):
    query_clean = " ".join(clean_text(query))
    q_vec = vectorizer.transform([query_clean])
    sims = cosine_similarity(q_vec, tfidf_matrix).flatten()
    
    df_temp = df.copy()
    df_temp["similarity"] = sims
    return df_temp.sort_values("similarity", ascending=False).head(top_n)

# %%
results = search_papers("digital health apps for chronic disease")
results[["title", "similarity", "topic_name"]]
# Out:
#                                                   title  similarity  \
# 322   MedMetaverse: Medical Care of Chronic Disease ...    0.326781
# 691   Understanding the digital health care experien...    0.307380
# 1048  Precision medicine in the era of artificial in...    0.274193
# 20    Digital Health Literacy and Its Association Wi...    0.257641
# 1062  Trust Me, I’m a Doctor – User Perceptions of A...    0.255837
# 478   The need for a new generation of digital menta...    0.242675
# 1123  Artificial Intelligence-Based Conversational A...    0.233021
# 90    The application of artificial intelligence in ...    0.230992
# 251   Improving health literacy using the power of d...    0.224466
# 745   Selected health behaviors associated with heal...    0.221261
# 795   Digital Technologies and Data Science as Healt...    0.217185
# 386   The Effectiveness of Publicly Available Web-Ba...    0.215558
# 917   Potential value and impact of data mining and ...    0.209216
# 121   Trust and Inclusion in Digital Health: The Nee...    0.206716
# 37    The Importance of Digital Health Literacy in a...    0.205819
#
#                                              topic_name
# 322            Cancer Risk & Clinical Treatment Studies
# 691       Artificial Intelligence in Healthcare Systems
# 1048    Patient Monitoring & Chronic Disease Management
# 20           Machine Learning in Clinical Data Analysis
# 1062        Infectious Diseases (HIV & Lung Infections)
# 478          Machine Learning in Clinical Data Analysis
# 1123        Social Media & Digital Health Communication
# 90          Infectious Diseases (HIV & Lung Infections)
# 251   Mobile Health (mHealth) Applications & Health ...
# 745       Artificial Intelligence in Healthcare Systems
# 795          Machine Learning in Clinical Data Analysis
# 386       Artificial Intelligence in Healthcare Systems
# 917         Infectious Diseases (HIV & Lung Infections)
# 121   Mobile Health (mHealth) Applications & Health ...
# 37           Machine Learning in Clinical Data Analysis

# %%
# Enrich Retrieved Results with Topic Modeling Context
# This attaches:
# - dominant topic
# - topic name
# - top words of that topic
# - keywords

def get_topic_top_words(topic_id, topn=10):
    return [w for w, _ in lda_model.show_topic(topic_id, topn=topn)]

def enrich_with_topic_info(df_subset):
    rows = []
    for _, row in df_subset.iterrows():
        topic_id = row["dominant_topic"]
        topic_label = topic_names.get(topic_id, f"Topic {topic_id}")
        top_words = get_topic_top_words(topic_id, topn=10)
        
        rows.append({
            "title": row["title"],
            "authors": row["authors"],
            "pub_year": row["pub_year"],
            "journal": row["journal"],
            "similarity": row["similarity"],
            "topic_id": topic_id,
            "topic_name": topic_label,
            "topic_top_words": ", ".join(top_words),
            "keywords": row.get("keywords", "")
        })
    return pd.DataFrame(rows)

# %%
enriched = enrich_with_topic_info(results)
enriched.head()
# Out:
#                                                title  \
# 0  MedMetaverse: Medical Care of Chronic Disease ...
# 1  Understanding the digital health care experien...
# 2  Precision medicine in the era of artificial in...
# 3  Digital Health Literacy and Its Association Wi...
# 4  Trust Me, I’m a Doctor – User Perceptions of A...
#
#                                              authors  pub_year  \
# 0  Dileep Kumar Murala, Sandeep Kumar Panda, Suja...      2023
# 1  Na-Young Park, Nan‐He Yoon, Nam Soo Park, Youn...      2022
# 2  Murugan Subramanian, Anne Wojtusciszyn, Lucie ...      2020
# 3  Eva Yuen, Natalie Winter, Feby Savira, Catheri...      2024
# 4     Matthias Baldauf, Peter Fröehlich, Rainer Endl      2020
#
#                                             journal  similarity  topic_id  \
# 0                                       IEEE Access    0.326781        18
# 1  Korean Journal of Health Education and Promotion    0.307380        15
# 2                 Journal of Translational Medicine    0.274193        13
# 3           Interactive Journal of Medical Research    0.257641         8
# 4                                    Unknown Source    0.255837         5
#
#                                         topic_name  \
# 0         Cancer Risk & Clinical Treatment Studies
# 1    Artificial Intelligence in Healthcare Systems
# 2  Patient Monitoring & Chronic Disease Management
# 3       Machine Learning in Clinical Data Analysis
# 4      Infectious Diseases (HIV & Lung Infections)
#
#                                      topic_top_words  \
# 0  data, system, privacy, security, patient, bloc...
# 1  literacy, digital, study, student, education, ...
# 2  mental, human, interaction, social, service, j...
# 3  digital, care, technology, trust, tool, need, ...
# 4  healthcare, model, decision, intelligence, lea...
#
#                                             keywords
# 0  Wearable computer, Computer science, Variety (...
# 1  eHealth, Health literacy, Health care, Literac...
# 2  Disease, Life expectancy, Medicine, Exposome, ...
# 3  Health literacy, Literacy, Digital health, Ass...
# 4  Mobile apps, Computer science, Perception, Int...

# %%
# Topic‑wise Breakdown for the Query
# This shows:
# - top topics appearing in the retrieved set
# - their top words
# - top articles within those topics
def top_articles_per_topic_in_results(results_df, top_n_topics=3, top_n_articles=3):
    topic_counts = results_df["dominant_topic"].value_counts().head(top_n_topics).index
    
    out = {}
    for t in topic_counts:
        topic_label = topic_names.get(t, f"Topic {t}")
        top_words = get_topic_top_words(t, topn=10)
        
        subset = results_df[results_df["dominant_topic"] == t]
        subset = subset.sort_values("similarity", ascending=False).head(top_n_articles)
        
        out[t] = {
            "topic_name": topic_label,
            "top_words": top_words,
            "top_articles": subset[["title", "authors", "pub_year", "journal", "similarity"]]
        }
    return out

# %%
topic_view = top_articles_per_topic_in_results(results)
topic_view
# Out:
# {8: {'topic_name': 'Machine Learning in Clinical Data Analysis',
#   'top_words': ['digital',
#    'care',
#    'technology',
#    'trust',
#    'tool',
#    'need',
#    'clinical',
#    'literacy',
#    'use',
#    'approach'],
#   'top_articles':                                                  title  \
#   20   Digital Health Literacy and Its Association Wi...
#   478  The need for a new generation of digital menta...
#   795  Digital Technologies and Data Science as Healt...
#
#                                                  authors  pub_year  \
#   20   Eva Yuen, Natalie Winter, Feby Savira, Catheri...      2024
#   478     John Torous, Keris Jän Myrick, Adrián Aguilera      2023
#   795                                   João V. Cordeiro      2021
#
#                                        journal  similarity
#   20   Interactive Journal of Medical Research    0.257641
#   478                         World Psychiatry    0.242675
#   795                    Frontiers in Medicine    0.217185  },
#  5: {'topic_name': 'Infectious Diseases (HIV & Lung Infections)',
#   'top_words': ['healthcare',
#    'model',
#    'decision',
#    'intelligence',
#    'learning',
#    'artificial',
#    'trust',
#    'xai',
#    'human',
#    'research'],
#   'top_articles':                                                   title  \
#   1062  Trust Me, I’m a Doctor – User Perceptions of A...
#   90    The application of artificial intelligence in ...
#   917   Potential value and impact of data mining and ...
#
#                                                   authors  pub_year  \
#   1062     Matthias Baldauf, Peter Fröehlich, Rainer Endl      2020
#   90                          Sam Weingott, Joy Parkinson      2024
#   917   Maryam Saberi‐Karimian, Zahra Khorasanchi, Ham...      2021
#
#                                                  journal  similarity
#   1062                                    Unknown Source    0.255837
#   90                          Health Marketing Quarterly    0.230992
#   917   Critical Reviews in Clinical Laboratory Sciences    0.209216  },
#  15: {'topic_name': 'Artificial Intelligence in Healthcare Systems',
#   'top_words': ['literacy',
#    'digital',
#    'study',
#    'student',
#    'education',
#    'level',
#    'information',
#    'use',
#    'healthcare',
#    'among'],
#   'top_articles':                                                  title  \
#   691  Understanding the digital health care experien...
#   745  Selected health behaviors associated with heal...
#   386  The Effectiveness of Publicly Available Web-Ba...
#
#                                                  authors  pub_year  \
#   691  Na-Young Park, Nan‐He Yoon, Nam Soo Park, Youn...      2022
#   745            Eun Jin Choi, Heeran Chun, Woosung Kwak      2022
#   386                              Lars König, Ralf Suhr      2023
#
#                                                 journal  similarity
#   691  Korean Journal of Health Education and Promotion    0.307380
#   745  Korean Journal of Health Education and Promotion    0.221261
#   386              Journal of Medical Internet Research    0.215558  }}

# %%
#Build Keyword Co‑Occurrence Network (for visualization)
# This produces a network you can load into Gephi, Cytoscape, or NetworkX visualizations.
import itertools
import networkx as nx

def build_keyword_cooccurrence(df, min_freq=3):
    G = nx.Graph()
    
    for kw_list in df["author_kw_list"]:
        kws = [k for k in kw_list if k]
        for a, b in itertools.combinations(sorted(set(kws)), 2):
            if G.has_edge(a, b):
                G[a][b]["weight"] += 1
            else:
                G.add_edge(a, b, weight=1)
    
    # Filter weak edges
    edges_to_remove = [(u, v) for u, v, d in G.edges(data=True) if d["weight"] < min_freq]
    G.remove_edges_from(edges_to_remove)
    
    return G

keyword_graph = build_keyword_cooccurrence(df, min_freq=3)

# %%
edges_df = nx.to_pandas_edgelist(keyword_graph)
edges_df.to_csv("keyword_network_edges.csv", index=False)

# %%
import re
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

# Expanded scientific contribution patterns
CONTRIB_PATTERNS = [
    r"\bwe propose\b",
    r"\bwe present\b",
    r"\bwe introduce\b",
    r"\bwe develop\b",
    r"\bwe design\b",
    r"\bwe evaluate\b",
    r"\bwe investigate\b",
    r"\bwe examine\b",
    r"\bwe analyze\b",
    r"\bthis paper\b",
    r"\bthis study\b",
    r"\bin this paper\b",
    r"\bin this study\b",
    r"\bthe aim of this\b",
    r"\bthe objective of this\b",
    r"\bthe purpose of this\b"
]

# Compile regex for speed
CONTRIB_REGEX = re.compile("|".join(CONTRIB_PATTERNS), re.IGNORECASE)

def extract_what_paper_does(abstract, debug=False):
    """
    Extracts the main contribution sentence from a scientific abstract.
    Uses pattern matching + fallback scoring.
    """
    if pd.isna(abstract) or not str(abstract).strip():
        return ""
    
    text = str(abstract).strip()
    
    # Fix common formatting issues
    text = re.sub(r"\s+", " ", text)
    
    # Split into sentences
    sentences = sent_tokenize(text)
    if debug:
        print("\n--- Sentences ---")
        for s in sentences:
            print(s)
    
    # 1. Pattern-based extraction
    for s in sentences:
        if CONTRIB_REGEX.search(s):
            if debug:
                print("\nMatched pattern:", s)
            return s.strip()
    
    # 2. Fallback: choose the most "informative" sentence
    # Score sentences by length + presence of verbs
    def score_sentence(s):
        length_score = len(s.split())
        verb_score = len(re.findall(r"\b(is|are|was|were|be|have|has|propose|present|develop|evaluate|investigate)\b", s.lower()))
        return length_score + verb_score
    
    best_sentence = max(sentences, key=score_sentence)
    
    if debug:
        print("\nFallback selected:", best_sentence)
    
    return best_sentence.strip()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jasraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df["what_this_paper_does"] = df["abstract"].apply(extract_what_paper_does)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jasraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Jasraj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
extract_what_paper_does(df["abstract"].iloc[0], debug=True)
# Out:
# --- Sentences ---
# Comprehensive clinical documentation is crucial for effective healthcare delivery, yet it poses a significant burden on healthcare professionals, leading to burnout, increased medical errors, and compromised patient safety.
# This paper explores the potential of generative AI (Artificial Intelligence) to streamline the clinical documentation process, specifically focusing on generating SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes.
# We present a case study demonstrating the application of natural language processing (NLP) and automatic speech recognition (ASR) technologies to transcribe patient-clinician interactions, coupled with advanced prompting techniques to generate draft clinical notes using large language models (LLMs).
# The study highlights the benefits of this approach, including time savings, improved documentation quality, and enhanced patient-centered care.
# Additionally, we discuss ethical considerations, such as maintaining patient confidentiality and addressing model biases, underscoring the need for responsible deployment of generative AI in healthcare settings.
# The findings suggest that generative AI has the potential to revolutionize clinical documentation practices, alleviating administrative burdens and enabling healthcare professionals to focus more on direct patient care.
#
# Matched pattern: This paper explores the potential of generative AI (Artificial Intelligence) to streamline the clinical documentation process, specifically focusing on generating SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes.
# 'This paper explores the potential of generative AI (Artificial Intelligence) to streamline the clinical documentation process, specifically focusing on generating SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes.'

# %%
import re

def split_sentences_fast(text):
    # Split on ., ?, ! but keep punctuation
    parts = re.split(r'(?<=[.!?])\s+', text)
    return [p.strip() for p in parts if p.strip()]

# %%
CONTRIB_PATTERNS = [
    r"\bwe propose\b",
    r"\bwe present\b",
    r"\bwe introduce\b",
    r"\bwe develop\b",
    r"\bwe design\b",
    r"\bwe evaluate\b",
    r"\bwe investigate\b",
    r"\bwe examine\b",
    r"\bwe analyze\b",
    r"\bthis paper\b",
    r"\bthis study\b",
    r"\bin this paper\b",
    r"\bin this study\b",
    r"\bthe aim of this\b",
    r"\bthe objective of this\b",
    r"\bthe purpose of this\b"
]

CONTRIB_REGEX = re.compile("|".join(CONTRIB_PATTERNS), re.IGNORECASE)

def extract_what_paper_does(abstract, debug=False):
    if pd.isna(abstract) or not str(abstract).strip():
        return ""
    
    text = str(abstract).strip()
    text = re.sub(r"\s+", " ", text)  # normalize whitespace
    
    # 1. Split into sentences
    sentences = split_sentences_fast(text)
    if debug:
        print("\n--- Sentences ---")
        for s in sentences:
            print(s)
    
    # 2. Pattern-based extraction
    for s in sentences:
        if CONTRIB_REGEX.search(s):
            if debug:
                print("\nMatched:", s)
            return s.strip()
    
    # 3. Fallback: choose the most informative sentence
    def score_sentence(s):
        length_score = len(s.split())
        verb_score = len(re.findall(
            r"\b(is|are|was|were|be|have|has|propose|present|develop|evaluate|investigate)\b",
            s.lower()
        ))
        return length_score + verb_score
    
    best_sentence = max(sentences, key=score_sentence)
    
    if debug:
        print("\nFallback:", best_sentence)
    
    return best_sentence.strip()

# %%
df["what_this_paper_does"] = df["abstract"].apply(extract_what_paper_does)

# %%
extract_what_paper_does(df["abstract"].iloc[0], debug=True)
# Out:
# --- Sentences ---
# Comprehensive clinical documentation is crucial for effective healthcare delivery, yet it poses a significant burden on healthcare professionals, leading to burnout, increased medical errors, and compromised patient safety.
# This paper explores the potential of generative AI (Artificial Intelligence) to streamline the clinical documentation process, specifically focusing on generating SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes.
# We present a case study demonstrating the application of natural language processing (NLP) and automatic speech recognition (ASR) technologies to transcribe patient-clinician interactions, coupled with advanced prompting techniques to generate draft clinical notes using large language models (LLMs).
# The study highlights the benefits of this approach, including time savings, improved documentation quality, and enhanced patient-centered care.
# Additionally, we discuss ethical considerations, such as maintaining patient confidentiality and addressing model biases, underscoring the need for responsible deployment of generative AI in healthcare settings.
# The findings suggest that generative AI has the potential to revolutionize clinical documentation practices, alleviating administrative burdens and enabling healthcare professionals to focus more on direct patient care.
#
# Matched: This paper explores the potential of generative AI (Artificial Intelligence) to streamline the clinical documentation process, specifically focusing on generating SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes.
# 'This paper explores the potential of generative AI (Artificial Intelligence) to streamline the clinical documentation process, specifically focusing on generating SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes.'

# %%
final_cols = [
    "title",
    "authors",
    "pub_year",
    "journal",
    "keywords",
    "dominant_topic",
    "topic_name",
    "what_this_paper_does"
]

spreadsheet_df = df[final_cols]
spreadsheet_df.to_csv("paper_database_with_contribution.csv", index=False)
